# %%
import pandas as pd
import numpy as n

# %%
# unstable UST
# unglued UG
# unfinity UF

# %%
# original read-in of data
df = pd.read_csv('cards.csv')

df.head()
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (3,11,18,22,26,29,53,59,60,67,68,77,78,85,86) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    index  id        artist asciiName  attractionLights availability  \
# 0      0   1  Pete Venters       NaN               NaN   mtgo,paper
# 1      1   2  Pete Venters       NaN               NaN   mtgo,paper
# 2      2   3   Volkan Baǵa       NaN               NaN   mtgo,paper
# 3      3   4   Volkan Baǵa       NaN               NaN   mtgo,paper
# 4      4   5      Mark Zug       NaN               NaN   mtgo,paper
#
#   boosterTypes borderColor  cardKingdomEtchedId  cardKingdomFoilId  ...  \
# 0        draft       black                  NaN                NaN  ...
# 1        draft       black                  NaN           123087.0  ...
# 2        draft       black                  NaN                NaN  ...
# 3        draft       black                  NaN           123088.0  ...
# 4        draft       black                  NaN                NaN  ...
#
#    supertypes tcgplayerEtchedProductId  tcgplayerProductId  \
# 0         NaN                      NaN             15032.0
# 1         NaN                      NaN             15032.0
# 2         NaN                      NaN             15033.0
# 3         NaN                      NaN             15033.0
# 4         NaN                      NaN             15035.0
#
#                                                 text toughness  \
# 0  First strike (This creature deals combat damag...         4
# 1  First strike (This creature deals combat damag...         4
# 2  Flying\nWhen Angel of Mercy enters the battlef...         3
# 3  Flying\nWhen Angel of Mercy enters the battlef...         3
# 4  Target creature gets +3/+3 and gains flying un...       NaN
#
#                       type     types                                  uuid  \
# 0  Creature — Human Cleric  Creature  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# 1  Creature — Human Cleric  Creature  b7c19924-b4bf-56fc-aa73-f586e940bd42
# 2         Creature — Angel  Creature  57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 3         Creature — Angel  Creature  8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a
# 4                  Sorcery   Sorcery  55bd38ca-dc73-5c06-8f80-a6ddd2f44382
#
#                              variations  watermark
# 0  b7c19924-b4bf-56fc-aa73-f586e940bd42        NaN
# 1  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c        NaN
# 2  8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a        NaN
# 3  57aaebc1-850c-503d-9f6e-bb8d00d8bf7c        NaN
# 4  c5655330-5131-5f40-9d3e-0549d88c6e9e        NaN
#
# [5 rows x 98 columns]

# %%
df.columns
# Out:
# Index(['index', 'id', 'artist', 'asciiName', 'attractionLights',
#        'availability', 'boosterTypes', 'borderColor', 'cardKingdomEtchedId',
#        'cardKingdomFoilId', 'cardKingdomId', 'cardParts', 'cardsphereId',
#        'colorIdentity', 'colorIndicator', 'colors', 'convertedManaCost',
#        'defense', 'duelDeck', 'edhrecRank', 'edhrecSaltiness',
#        'faceConvertedManaCost', 'faceFlavorName', 'faceManaValue', 'faceName',
#        'finishes', 'flavorName', 'flavorText', 'frameEffects', 'frameVersion',
#        'hand', 'hasAlternativeDeckLimit', 'hasContentWarning', 'hasFoil',
#        'hasNonFoil', 'isAlternative', 'isFullArt', 'isFunny', 'isOnlineOnly',
#        'isOversized', 'isPromo', 'isRebalanced', 'isReprint', 'isReserved',
#        'isStarter', 'isStorySpotlight', 'isTextless', 'isTimeshifted',
#        'keywords', 'language', 'layout', 'leadershipSkills', 'life', 'loyalty',
#        'manaCost', 'manaValue', 'mcmId', 'mcmMetaId', 'mtgArenaId',
#        'mtgjsonFoilVersionId', 'mtgjsonNonFoilVersionId', 'mtgjsonV4Id',
#        'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'number',
#        'originalPrintings', 'originalReleaseDate', 'originalText',
#        'originalType', 'otherFaceIds', 'power', 'printings', 'promoTypes',
#        'purchaseUrls', 'rarity', 'rebalancedPrintings', 'relatedCards',
#        'scryfallId', 'scryfallIllustrationId', 'scryfallOracleId',
#        'securityStamp', 'setCode', 'side', 'signature', 'subsets', 'subtypes',
#        'supertypes', 'tcgplayerEtchedProductId', 'tcgplayerProductId', 'text',
#        'toughness', 'type', 'types', 'uuid', 'variations', 'watermark'],
#       dtype='object')

# %%
# list of useful columns

cols = [
    
        # columns I'm keeping
        'id', 
        'name',
        'manaCost', 
        'manaValue',
        'colors', 
        'colorIdentity',   
        'types', 
        'subtypes',
        'supertypes',
        'text',
        'power',     
        'toughness', 
        'loyalty',
        'defense',
        'leadershipSkills',
        'setCode', 
        'subsets',
    
        # columns for filtering 
        'isFunny', 
        'isOnlineOnly',
        'isOversized'        ]

# %%
df = df[cols]

df = df[df.isFunny == False]

df = df[df.isOnlineOnly == False]

df = df[df.isOversized == False]

df = df.drop(columns = ['isFunny', 'isOnlineOnly', 'isOversized'])

# %%
df
# Out:
#           id                 name   manaCost  manaValue colors colorIdentity  \
# 0          1    Ancestor's Chosen  {5}{W}{W}        7.0      W             W
# 1          2    Ancestor's Chosen  {5}{W}{W}        7.0      W             W
# 2          3       Angel of Mercy     {4}{W}        5.0      W             W
# 3          4       Angel of Mercy     {4}{W}        5.0      W             W
# 4          5     Angelic Blessing     {2}{W}        3.0      W             W
# ...      ...                  ...        ...        ...    ...           ...
# 80274  80275        Into the Roil     {1}{U}        2.0      U             U
# 80275  80276  Bloodchief's Thirst        {B}        1.0      B             B
# 80276  80277        Roil Eruption     {1}{R}        2.0      R             R
# 80277  80278     Roiling Regrowth     {2}{G}        3.0      G             G
# 80278  80279     Kargan Warleader  {1}{R}{W}        3.0    R,W           R,W
#
#           types       subtypes supertypes  \
# 0      Creature   Human,Cleric        NaN
# 1      Creature   Human,Cleric        NaN
# 2      Creature          Angel        NaN
# 3      Creature          Angel        NaN
# 4       Sorcery            NaN        NaN
# ...         ...            ...        ...
# 80274   Instant            NaN        NaN
# 80275   Sorcery            NaN        NaN
# 80276   Sorcery            NaN        NaN
# 80277   Instant            NaN        NaN
# 80278  Creature  Human,Warrior        NaN
#
#                                                     text power toughness  \
# 0      First strike (This creature deals combat damag...     4         4
# 1      First strike (This creature deals combat damag...     4         4
# 2      Flying\nWhen Angel of Mercy enters the battlef...     3         3
# 3      Flying\nWhen Angel of Mercy enters the battlef...     3         3
# 4      Target creature gets +3/+3 and gains flying un...   NaN       NaN
# ...                                                  ...   ...       ...
# 80274  Kicker {1}{U} (You may pay an additional {1}{U...   NaN       NaN
# 80275  Kicker {2}{B} (You may pay an additional {2}{B...   NaN       NaN
# 80276  Kicker {5} (You may pay an additional {5} as y...   NaN       NaN
# 80277  Sacrifice a land. Search your library for up t...   NaN       NaN
# 80278              Other Warriors you control get +1/+1.     3         3
#
#       loyalty  defense leadershipSkills setCode subsets
# 0         NaN      NaN              NaN     10E     NaN
# 1         NaN      NaN              NaN     10E     NaN
# 2         NaN      NaN              NaN     10E     NaN
# 3         NaN      NaN              NaN     10E     NaN
# 4         NaN      NaN              NaN     10E     NaN
# ...       ...      ...              ...     ...     ...
# 80274     NaN      NaN              NaN     ZNR     NaN
# 80275     NaN      NaN              NaN     ZNR     NaN
# 80276     NaN      NaN              NaN     ZNR     NaN
# 80277     NaN      NaN              NaN     ZNR     NaN
# 80278     NaN      NaN              NaN     ZNR     NaN
#
# [70111 rows x 17 columns]
