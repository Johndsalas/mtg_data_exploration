# %%
import pandas as pd
import numpy as n

# %%
df = pd.read_csv('cards.csv')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (3,11,18,22,26,29,53,59,60,67,68,77,78,85,86) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    index  id        artist asciiName  attractionLights availability  \
# 0      0   1  Pete Venters       NaN               NaN   mtgo,paper
# 1      1   2  Pete Venters       NaN               NaN   mtgo,paper
# 2      2   3   Volkan Baǵa       NaN               NaN   mtgo,paper
# 3      3   4   Volkan Baǵa       NaN               NaN   mtgo,paper
# 4      4   5      Mark Zug       NaN               NaN   mtgo,paper
#
#   boosterTypes borderColor  cardKingdomEtchedId  cardKingdomFoilId  ...  \
# 0        draft       black                  NaN                NaN  ...
# 1        draft       black                  NaN           123087.0  ...
# 2        draft       black                  NaN                NaN  ...
# 3        draft       black                  NaN           123088.0  ...
# 4        draft       black                  NaN                NaN  ...
#
#    supertypes tcgplayerEtchedProductId  tcgplayerProductId  \
# 0         NaN                      NaN             15032.0
# ...

# %%
df.columns
# Out:
# Index(['index', 'id', 'artist', 'asciiName', 'attractionLights',
#        'availability', 'boosterTypes', 'borderColor', 'cardKingdomEtchedId',
#        'cardKingdomFoilId', 'cardKingdomId', 'cardParts', 'cardsphereId',
#        'colorIdentity', 'colorIndicator', 'colors', 'convertedManaCost',
#        'defense', 'duelDeck', 'edhrecRank', 'edhrecSaltiness',
#        'faceConvertedManaCost', 'faceFlavorName', 'faceManaValue', 'faceName',
#        'finishes', 'flavorName', 'flavorText', 'frameEffects', 'frameVersion',
#        'hand', 'hasAlternativeDeckLimit', 'hasContentWarning', 'hasFoil',
#        'hasNonFoil', 'isAlternative', 'isFullArt', 'isFunny', 'isOnlineOnly',
#        'isOversized', 'isPromo', 'isRebalanced', 'isReprint', 'isReserved',
#        'isStarter', 'isStorySpotlight', 'isTextless', 'isTimeshifted',
#        'keywords', 'language', 'layout', 'leadershipSkills', 'life', 'loyalty',
#        'manaCost', 'manaValue', 'mcmId', 'mcmMetaId', 'mtgArenaId',
# ...

# %%
df.size
# Out:
# 7867342

# %%
len(df[['name','text']][df.name == "Power Sink"])
# Out:
# 23

# %%
cols =  [
         'id', 
         'name',
         'text',
         'artist', 
         'colorIdentity', 
         'colors', 
         'manaCost', 
         'manaValue',
         'convertedManaCost',
         'defense', 
         'faceConvertedManaCost', 
         'faceManaValue', 
         'faceName',
         'flavorText', 
         'isFunny', 
         'isOnlineOnly',
         'isOversized', 
         'leadershipSkills', 
         'life', 
         'loyalty',
  
         'power', 
         'setCode', 
         'subsets', 
         'subtypes',
         'supertypes',
         'toughness', 
         'type', 
         'types'
        ]

# %%
df[cols].sort_values('name', ascending = False)[df.isFunny == False][df.setCode != "UNF"].head(10)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           id                  name  \
# 47834  47835  Zurzoth, Chaos Rider
# 33949  33950  Zurzoth, Chaos Rider
# 46693  46694      Zurgo and Ojutai
# 46764  46765      Zurgo and Ojutai
# 36162  36163     Zurgo Helmsmasher
# 58994  58995     Zurgo Helmsmasher
# 22153  22154     Zurgo Helmsmasher
# 68476  68477     Zurgo Helmsmasher
# 54849  54850     Zurgo Helmsmasher
# 25321  25322     Zurgo Bellstriker
#
#                                                     text              artist  \
# 47834  Whenever an opponent draws their first card ea...       Dmitry Burmak
# 33949  Whenever an opponent draws their first card ea...       Dmitry Burmak
# 46693  Flying, haste\nZurgo and Ojutai has hexproof a...             Daarken
# ...

# %%
df[df.name == "Swords to Plowshares"]
# Out:
#        index     id          artist asciiName  attractionLights availability  \
# 548      548    549  Jeff A. Menges       NaN               NaN        paper
# 1812    1812   1813  Jeff A. Menges       NaN               NaN        paper
# 2109    2109   2110  Jeff A. Menges       NaN               NaN        paper
# 2407    2407   2408  Jeff A. Menges       NaN               NaN        paper
# 3030    3030   3031   Diego Gisbert       NaN               NaN        paper
# ...      ...    ...             ...       ...               ...          ...
# 71121  71121  71122     Kaja Foglio       NaN               NaN         mtgo
# 75934  75934  75935  Terese Nielsen       NaN               NaN   mtgo,paper
# 76244  76244  76245  Terese Nielsen       NaN               NaN         mtgo
# 76617  76617  76618   Jesper Ejsing       NaN               NaN        paper
# 78199  78199  78200     Kaja Foglio       NaN               NaN        paper
#
# ...
